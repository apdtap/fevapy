# %% [markdown]
# <a href="https://colab.research.google.com/github/apdtap/fevapy/blob/master/1911_date_yahoo_exchange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import yfinance as yf
import matplotlib as pl
import pandas as df
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.50-py2.py3-none-any.whl size=21556 sha256=d282ce742a8cf35a3475852d78084a0e8c175372c7fd5884e913df98b3c5cb85
#   Stored in directory: /root/.cache/pip/wheels/19/2a/e6/b4d4cc977576e18220a36866acf2f2cf7241f16af5f8795b17
# Successfully built yfinance
# ...

# %%
USDxCNY=yf.download('USDCNY=X','2005-01-01')
USDxCNY.Open.plot()
USDxCNY.Open.loc['2019-11-29']
USDxCNY.loc['2019-10-23']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Open         7.0761
# High         7.0851
# Low          7.0605
# Close        7.0762
# Adj Close    7.0762
# Volume       0.0000
# Name: 2019-10-23 00:00:00, dtype: float64

# %%
CNYxUSD=yf.download('CNYUSD=X','2019-1-1')
CNYxUSD.Open.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
from google.colab import files
USDxCNY.to_csv('usdcny16_19.csv') 
files.download('usdcny16_19.csv')

# %%
USDxCNY.loc['2019-10-23']
# Out:
# Open         7.0761
# High         7.0851
# Low          7.0605
# Close        7.0762
# Adj Close    7.0762
# Volume       0.0000
# Name: 2019-10-23 00:00:00, dtype: float64

# %%
CNYxUSD.loc['2019-10-23']
# Out:
# Open         0.141321
# High         0.141633
# Low          0.141141
# Close        0.141319
# Adj Close    0.141319
# Volume       0.000000
# Name: 2019-10-23 00:00:00, dtype: float64

# %%
JPYxHKD=yf.download('JPYHKD=X','2001-01-01')
JPYxHKD.Open.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # New Section

# %%
USDxCNY=yf.download('USDCNY=X','2017-01-01')
USDxCNY.Close.plot()
USDxCNY.Close.loc['2019-11-29']
USDxCNY.loc['2019-11-29']
USDxCNY.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2017-01-02  6.9438  6.9462  6.9350  6.9438     6.9438       0
# 2017-01-03  6.9440  6.9604  6.9350  6.9440     6.9440       0
# 2017-01-04  6.9599  6.9601  6.9343  6.9598     6.9598       0
# 2017-01-05  6.9341  6.9341  6.8605  6.9251     6.9251       0
# 2017-01-06  6.8880  6.9255  6.8741  6.8879     6.8879       0

# %%
CNYxUSD=yf.download('CNYUSD=X','2017-01-01')
CNYxUSD
CNYxUSD.Close.plot()
CNYxUSD.Close.loc['2019-11-04']
CNYxUSD.loc['2019-11-04']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Open         0.142118
# High         0.142531
# Low          0.142116
# Close        0.142118
# Adj Close    0.142118
# Volume       0.000000
# Name: 2019-11-04 00:00:00, dtype: float64

# %%
JPYxHKD=yf.download('JPYHKD=X','2017-01-01')
JPYxHKD
JPYxHKD.Close.plot()
JPYxHKD.loc['2019-11-01']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Open         0.072540
# High         0.072625
# Low          0.072410
# Close        0.072561
# Adj Close    0.072561
# Volume       0.000000
# Name: 2019-11-01 00:00:00, dtype: float64

# %%
CHFxHKD=yf.download('CHFHKD=X','2011-05-01')
CHFxHKD
CHFxHKD.Close.plot()
CHFxHKD.loc['2019-11-01']
# Out:
# [*********************100%***********************]  1 of 1 completed
# Open         7.94322
# High         7.95230
# Low          7.92166
# Close        7.94379
# Adj Close    7.94379
# Volume       0.00000
# Name: 2019-11-01 00:00:00, dtype: float64

# %%
CHFxHKD=yf.download('CHFHKD=X','2011-04-01','2015-05-01')
CHFxHKD
CHFxHKD.Close.plot()
CHFxHKD.loc['2011-04-14']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec35939886ad> in <module>
# ----> 1 CHFxHKD=yf.download('CHFHKD=X','2011-04-01','2015-05-01')
#       2 CHFxHKD
#       3 CHFxHKD.Close.plot()
#       4 CHFxHKD.loc['2011-04-14']
#
# NameError: name 'yf' is not defined

# %%
#CHFxHKD=CHFxHKD.set_index('Date')
print(CHFxHKD.head(30))
CHFxHKD.loc('2011-04-25')=CHFxHKD.loc('2011-04-25')*100
# Out:
#   File "<ipython-input-59-5afabc5d3c36>", line 3
#     CHFxHKD.loc('2011-04-25')=CHFxHKD.loc('2011-04-25')*100
#                                                            ^
# SyntaxError: can't assign to function call
